# %%
import pandas as pd
import os

# %% [markdown]
# **Merge the 12 months of sales data into a single csv file**

# %%
df = pd.read_csv('./Sales_Data/Sales_April_2019.csv')


files = [file for file in os.listdir('./Sales_Data')]

all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('./Sales_Data/'+file)
    all_months_data = pd.concat([all_months_data, df])

all_months_data.to_csv('all_data.csv', index=False)

# %% [markdown]
# **Read in updated dataframe**

# %%
all_data = pd.read_csv('all_data.csv')
all_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %% [markdown]
# **CLEAN DATA**

# %% [markdown]
# **Drop rows in NaN**

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()

all_data = all_data.dropna(how='all')
all_data
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 186845   295660    AAA Batteries (4-pack)                2       2.99
# 186846   295661      USB-C Charging Cable                1      11.95
# 186847   295662  Lightning Charging Cable                1      14.95
# 186848   295663    AAA Batteries (4-pack)                1       2.99
# 186849   295664              Google Phone                1        600
#
#             Order Date                       Purchase Address Month
# 0       01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1       01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2       01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3       01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4       01/25/19 11:59          387 10th St, Austin, TX 73301    01
# ...                ...                                    ...   ...
# 186845  11/04/19 14:17      574 4th St, Los Angeles, CA 90001    11
# 186846  11/23/19 07:22           359 1st St, Austin, TX 73301    11
# 186847  11/13/19 16:12          900 10th St, Boston, MA 02215    11
# 186848  11/17/19 17:08        592 Sunset St, Boston, MA 02215    11
# 186849  11/17/19 16:13       428 Jackson St, Boston, MA 02215    11
#
# [186305 rows x 7 columns]

# %% [markdown]
# **Find 'Or' and delete it**

# %%
all_data = all_data[all_data['Order Date'].str[0:2] != 'Or']
all_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    01

# %% [markdown]
# **convert columns to correct type**

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

all_data
# Out:
# /tmp/ipykernel_29946/4056222198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
# /tmp/ipykernel_29946/4056222198.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        141234                    iPhone                 1      700.00
# 1        141235  Lightning Charging Cable                 1       14.95
# 2        141236          Wired Headphones                 2       11.99
# 3        141237          27in FHD Monitor                 1      149.99
# 4        141238          Wired Headphones                 1       11.99
# ...         ...                       ...               ...         ...
# 186845   295660    AAA Batteries (4-pack)                 2        2.99
# 186846   295661      USB-C Charging Cable                 1       11.95
# 186847   295662  Lightning Charging Cable                 1       14.95
# 186848   295663    AAA Batteries (4-pack)                 1        2.99
# 186849   295664              Google Phone                 1      600.00
#
#             Order Date                       Purchase Address Month
# 0       01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1       01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2       01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3       01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4       01/25/19 11:59          387 10th St, Austin, TX 73301    01
# ...                ...                                    ...   ...
# 186845  11/04/19 14:17      574 4th St, Los Angeles, CA 90001    11
# 186846  11/23/19 07:22           359 1st St, Austin, TX 73301    11
# 186847  11/13/19 16:12          900 10th St, Boston, MA 02215    11
# 186848  11/17/19 17:08        592 Sunset St, Boston, MA 02215    11
# 186849  11/17/19 16:13       428 Jackson St, Boston, MA 02215    11
#
# [185950 rows x 7 columns]

# %% [markdown]
# **Add additional columns**

# %% [markdown]
# **Add month column**

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
# Out:
# /tmp/ipykernel_29946/1369745424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month'] = all_data['Order Date'].str[0:2]
# /tmp/ipykernel_29946/1369745424.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month'] = all_data['Month'].astype('int32')
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address  Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301      1

# %% [markdown]
# **Add sales column**

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head()
# Out:
# /tmp/ipykernel_29946/4089898328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address  Month   Sales
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301      1   11.99

# %% [markdown]
# **Add city column**

# %%
def get_city(address):
    return address.split(',')[1]

def get_state(address):
    return address.split(',')[2].split(' ')[1]

all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)} ({get_state(x)})")

all_data.head()
# Out:
# /tmp/ipykernel_29946/696615924.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)} ({get_state(x)})")
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address  Month   Sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301      1   11.99
#
#                   City
# 0          Boston (MA)
# 1        Portland (OR)
# 2   San Francisco (CA)
# 3     Los Angeles (CA)
# 4          Austin (TX)

# %% [markdown]
# **Q1).What was the best month for sales?How much was earned that month?**

# %%
results = all_data.groupby('Month').sum()
results
# Out:
#                                                 Order ID  \
# Month
# 1      1412341412351412361412371412381412391412401412...
# 2      1452121453721464421473091476631489871505021505...
# 3      1505331505411508121517491520361532841535441538...
# 4      1765581765591765601765601765611765621765631765...
# 5      1940951940961940971940981940991941001941011941...
# 6      1957481958691960721961321966381966391976981990...
# 7      2229102229112229122229132229142229152229162229...
# 8      2237102255412256582271152275212275212277322296...
# 9      2481512481522481532481542481552481562481572481...
# 10     2486432501392501392502752506842512432521642522...
# 11     2611272617352629282631622636192644072661352680...
# 12     2956652956662956672956682956692956702956712956...
#
#                                                  Product  Quantity Ordered  \
# Month
# 1      iPhoneLightning Charging CableWired Headphones...             10903
# 2      Lightning Charging CableAAA Batteries (4-pack)...             13449
# 3      AAA Batteries (4-pack)AAA Batteries (4-pack)Wi...             17005
# 4      USB-C Charging CableBose SoundSport Headphones...             20558
# 5      Wired HeadphonesAA Batteries (4-pack)27in FHD ...             18667
# 6      27in FHD MonitorAAA Batteries (4-pack)Lightnin...             15253
# 7      Apple Airpods HeadphonesFlatscreen TVAA Batter...             16072
# 8      Bose SoundSport Headphones27in 4K Gaming Monit...             13448
# 9      AA Batteries (4-pack)USB-C Charging CableUSB-C...             13109
# 10     Lightning Charging CableGoogle PhoneUSB-C Char...             22703
# 11     34in Ultrawide MonitorBose SoundSport Headphon...             19798
# 12     Macbook Pro LaptopLG Washing MachineUSB-C Char...             28114
#
#        Price Each                                         Order Date  \
# Month
# 1      1811768.38  01/22/19 21:2501/28/19 14:1501/17/19 13:3301/0...
# 2      2188884.72  02/01/19 00:3602/01/19 04:0202/01/19 01:4802/0...
# 3      2791207.83  03/01/19 03:0603/01/19 01:0303/01/19 02:1803/0...
# 4      3367671.02  04/19/19 08:4604/07/19 22:3004/12/19 14:3804/1...
# 5      3135125.13  05/16/19 17:1405/19/19 14:4305/24/19 11:3605/0...
# 6      2562025.61  06/01/19 03:2606/01/19 01:0606/01/19 00:1806/0...
# 7      2632539.56  07/26/19 16:5107/05/19 08:5507/29/19 12:4107/2...
# 8      2230345.42  08/01/19 01:5608/01/19 01:1508/01/19 01:1408/0...
# 9      2084992.09  09/17/19 14:4409/29/19 10:1909/16/19 17:4809/2...
# 10     3715554.83  10/01/19 01:3610/01/19 00:5310/01/19 00:5310/0...
# 11     3180600.68  11/01/19 01:4911/01/19 00:1011/01/19 02:3311/0...
# 12     4588415.41  12/30/19 00:0112/29/19 07:0312/12/19 18:2112/2...
#
#                                         Purchase Address       Sales  \
# Month
# 1      944 Walnut St, Boston, MA 02215185 Maple St, P...  1822256.73
# 2      484 6th St, Dallas, TX 75001459 West St, Dalla...  2202022.42
# 3      270 Dogwood St, San Francisco, CA 94016683 Ada...  2807100.38
# 4      917 1st St, Dallas, TX 75001682 Chestnut St, B...  3390670.24
# 5      669 2nd St, New York City, NY 10001844 Walnut ...  3152606.75
# 6      856 Elm St, San Francisco, CA 94016877 Center ...  2577802.26
# 7      389 South St, Atlanta, GA 30301590 4th St, Sea...  2647775.76
# 8      882 Lake St, San Francisco, CA 94016480 Spruce...  2244467.88
# 9      380 North St, Los Angeles, CA 90001511 8th St,...  2097560.13
# 10     321 Chestnut St, Austin, TX 73301132 10th St, ...  3736726.88
# 11     917 Madison St, Seattle, WA 98101582 Spruce St...  3199603.20
# 12     136 Church St, New York City, NY 10001562 2nd ...  4613443.34
#
#                                                     City
# Month
# 1       Boston (MA) Portland (OR) San Francisco (CA) ...
# 2       Dallas (TX) Dallas (TX) Los Angeles (CA) Dall...
# 3       San Francisco (CA) Portland (OR) San Francisc...
# 4       Dallas (TX) Boston (MA) Los Angeles (CA) Los ...
# 5       New York City (NY) Dallas (TX) New York City ...
# 6       San Francisco (CA) Dallas (TX) San Francisco ...
# 7       Atlanta (GA) Seattle (WA) Atlanta (GA) Atlant...
# 8       San Francisco (CA) Los Angeles (CA) Los Angel...
# 9       Los Angeles (CA) Austin (TX) Los Angeles (CA)...
# 10      Austin (TX) San Francisco (CA) San Francisco ...
# 11      Seattle (WA) Atlanta (GA) New York City (NY) ...
# 12      New York City (NY) New York City (NY) New Yor...

# %%
import matplotlib.pyplot as plt

months = range(1,13)

plt.bar(months, results['Sales'])
plt.xticks(months)
plt.ylabel('Sales in usd ($)')
plt.xlabel('Month Number')
# Out:
# Text(0.5, 0, 'Month Number')

# %% [markdown]
# **Answer: best month was December with 4613443.34 sales**

# %% [markdown]
# **Q2).What city had the highest number of sales**

# %%
all_data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address  Month   Sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301      1   11.99
#
#                   City
# 0          Boston (MA)
# 1        Portland (OR)
# 2   San Francisco (CA)
# 3     Los Angeles (CA)
# 4          Austin (TX)

# %%
results = all_data.groupby('City').sum()
results
# Out:
#                                                               Order ID  \
# City
#  Atlanta (GA)        1412531412611412811412891412961413111413471413...
#  Austin (TX)         1412381412481412751412751412771412951413051413...
#  Boston (MA)         1412341412511412631412651412711412731412791412...
#  Dallas (TX)         1412661412861412981412991413381413391413551413...
#  Los Angeles (CA)    1412371412401412421412461412501412521412551412...
#  New York City (NY)  1412641412681412721412781412821413011413141413...
#  Portland (ME)       1413291413721413951414071414091416531417681418...
#  Portland (OR)       1412351412491412561413021413081413301413361413...
#  San Francisco (CA)  1412361412391412411412431412441412451412471412...
#  Seattle (WA)        1412541412831412851413031413151413161413281413...
#
#                                                                Product  \
# City
#  Atlanta (GA)        AA Batteries (4-pack)USB-C Charging CableLight...
#  Austin (TX)         Wired HeadphonesFlatscreen TVUSB-C Charging Ca...
#  Boston (MA)         iPhoneApple Airpods HeadphonesBose SoundSport ...
#  Dallas (TX)         27in 4K Gaming Monitor27in 4K Gaming MonitorLi...
#  Los Angeles (CA)    27in FHD Monitor27in 4K Gaming MonitorBose Sou...
#  New York City (NY)  Apple Airpods HeadphonesAA Batteries (4-pack)A...
#  Portland (ME)       USB-C Charging CableAAA Batteries (4-pack)AAA ...
#  Portland (OR)       Lightning Charging Cable27in FHD MonitorGoogle...
#  San Francisco (CA)  Wired HeadphonesAAA Batteries (4-pack)USB-C Ch...
#  Seattle (WA)        AAA Batteries (4-pack)Flatscreen TVAAA Batteri...
#
#                      Quantity Ordered  Price Each  \
# City
#  Atlanta (GA)                   16602  2779908.20
#  Austin (TX)                    11153  1809873.61
#  Boston (MA)                    22528  3637409.77
#  Dallas (TX)                    16730  2752627.82
#  Los Angeles (CA)               33289  5421435.23
#  New York City (NY)             27932  4635370.83
#  Portland (ME)                   2750   447189.25
#  Portland (OR)                  11303  1860558.22
#  San Francisco (CA)             50239  8211461.74
#  Seattle (WA)                   16553  2733296.01
#
#                                                             Order Date  \
# City
#  Atlanta (GA)        01/17/19 00:0901/09/19 18:1401/05/19 16:5101/2...
#  Austin (TX)         01/25/19 11:5901/03/19 21:5401/07/19 16:0601/0...
#  Boston (MA)         01/22/19 21:2501/24/19 08:1301/11/19 23:3301/0...
#  Dallas (TX)         01/02/19 22:2101/02/19 20:3301/21/19 13:2401/3...
#  Los Angeles (CA)    01/05/19 20:3301/26/19 12:1601/01/19 10:3001/0...
#  New York City (NY)  01/03/19 09:4601/14/19 10:1301/12/19 13:0901/2...
#  Portland (ME)       01/01/19 16:0101/26/19 10:0701/29/19 16:2001/0...
#  Portland (OR)       01/28/19 14:1501/05/19 17:2001/29/19 10:4001/1...
#  San Francisco (CA)  01/17/19 13:3301/29/19 20:2201/05/19 12:0401/2...
#  Seattle (WA)        01/08/19 11:5101/02/19 16:1601/14/19 14:1301/1...
#
#                                                       Purchase Address  \
# City
#  Atlanta (GA)        385 11th St, Atlanta, GA 30301840 Lincoln St, ...
#  Austin (TX)         387 10th St, Austin, TX 73301363 Spruce St, Au...
#  Boston (MA)         944 Walnut St, Boston, MA 02215414 Walnut St, ...
#  Dallas (TX)         834 4th St, Dallas, TX 75001505 Hickory St, Da...
#  Los Angeles (CA)    738 10th St, Los Angeles, CA 90001979 Park St,...
#  New York City (NY)  937 Highland St, New York City, NY 10001611 El...
#  Portland (ME)       122 5th St, Portland, ME 04101134 Hickory St, ...
#  Portland (OR)       185 Maple St, Portland, OR 97035440 Cedar St, ...
#  San Francisco (CA)  538 Adams St, San Francisco, CA 94016775 Willo...
#  Seattle (WA)        238 Sunset St, Seattle, WA 9810168 Hickory St,...
#
#                       Month       Sales
# City
#  Atlanta (GA)        104794  2795498.58
#  Austin (TX)          69829  1819581.75
#  Boston (MA)         141112  3661642.01
#  Dallas (TX)         104620  2767975.40
#  Los Angeles (CA)    208325  5452570.80
#  New York City (NY)  175741  4664317.43
#  Portland (ME)        17144   449758.27
#  Portland (OR)        70621  1870732.34
#  San Francisco (CA)  315520  8262203.91
#  Seattle (WA)        104941  2747755.48

# %%
import matplotlib.pyplot as plt

cities = [city for city, df in all_data.groupby('City')]

plt.bar(cities, results['Sales'])
plt.xticks(cities, rotation='vertical', size=8)
plt.ylabel('Sales in usd ($)')
plt.xlabel('City Name')
# Out:
# Text(0.5, 0, 'City Name')

# %% [markdown]
# **Answer: San Francisco(CA)**

# %% [markdown]
# **Q3). What time should we display advertisements to maximize likelihood of customer's buying product?**

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])
all_data.head()
# Out:
# /tmp/ipykernel_159023/1435542791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order Date                       Purchase Address  Month   Sales  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215      1  700.00
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035      1   14.95
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016      1   23.98
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001      1  149.99
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301      1   11.99
#
#                   City
# 0          Boston (MA)
# 1        Portland (OR)
# 2   San Francisco (CA)
# 3     Los Angeles (CA)
# 4          Austin (TX)

# %%
all_data['Hour'] = all_data['Order Date'].dt.hour
all_data['Minutes'] = all_data['Order Date'].dt.minute
all_data.head()
# Out:
# /tmp/ipykernel_159023/2208201294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Hour'] = all_data['Order Date'].dt.hour
# /tmp/ipykernel_159023/2208201294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Minutes'] = all_data['Order Date'].dt.minute
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order Date                       Purchase Address  Month   Sales  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215      1  700.00
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035      1   14.95
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016      1   23.98
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001      1  149.99
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301      1   11.99
#
#                   City  Hour  Minute  Minutes  Seconds
# 0          Boston (MA)    21      25       25        0
# 1        Portland (OR)    14      15       15        0
# 2   San Francisco (CA)    13      33       33        0
# 3     Los Angeles (CA)    20      33       33        0
# 4          Austin (TX)    11      59       59        0

# %%
hours = [hour for hour, df in all_data.groupby('Hour')]

plt.plot(hours, all_data.groupby(['Hour']).count())
plt.xlabel('Hour')
plt.ylabel('Number of Orders')
plt.xticks(hours)
plt.grid()

# %% [markdown]
# **Answer: between 6pm and 7pm**

# %% [markdown]
# **Q4).What products are most often sold together**

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)]
df.head()
# Out:
#     Order ID                   Product  Quantity Ordered  Price Each  \
# 41    141275      USB-C Charging Cable                 1       11.95
# 42    141275          Wired Headphones                 1       11.99
# 57    141290  Apple Airpods Headphones                 1      150.00
# 58    141290     AA Batteries (4-pack)                 3        3.84
# 133   141365           Vareebadd Phone                 1      400.00
#
#              Order Date                        Purchase Address  Month  \
# 41  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301      1
# 42  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301      1
# 57  2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001      1
# 58  2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001      1
# 133 2019-01-10 11:19:00  20 Dogwood St, New York City, NY 10001      1
#
#       Sales                 City  Hour  Minute  Minutes  Seconds
# 41    11.95          Austin (TX)    16       6        6        0
# 42    11.99          Austin (TX)    16       6        6        0
# 57   150.00     Los Angeles (CA)     8      25       25        0
# 58    11.52     Los Angeles (CA)     8      25       25        0
# 133  400.00   New York City (NY)    11      19       19        0

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)]

df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

df = df[['Order ID', 'Grouped']].drop_duplicates()

df.head(100)
# Out:
# /tmp/ipykernel_159023/3677336673.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#      Order ID                                           Grouped
# 41     141275             USB-C Charging Cable,Wired Headphones
# 57     141290    Apple Airpods Headphones,AA Batteries (4-pack)
# 133    141365                  Vareebadd Phone,Wired Headphones
# 153    141384                 Google Phone,USB-C Charging Cable
# 220    141450           Google Phone,Bose SoundSport Headphones
# ...       ...                                               ...
# 2206   143326              Vareebadd Phone,USB-C Charging Cable
# 2238   143357     AAA Batteries (4-pack),27in 4K Gaming Monitor
# 2260   143378  Bose SoundSport Headphones,AA Batteries (4-pack)
# 2262   143379   34in Ultrawide Monitor,Lightning Charging Cable
# 2277   143393     Apple Airpods Headphones,USB-C Charging Cable
#
# [100 rows x 2 columns]

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key, value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# **Answer: 'iPhone', 'Lightning Charging Cable'**

# %% [markdown]
# **Q5). What product sold the most?Why do you think it sold the most?**

# %%
all_data.head(2)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
#
#            Order Date                  Purchase Address  Month   Sales  \
# 0 2019-01-22 21:25:00   944 Walnut St, Boston, MA 02215      1  700.00
# 1 2019-01-28 14:15:00  185 Maple St, Portland, OR 97035      1   14.95
#
#              City  Hour  Minute  Minutes  Seconds
# 0     Boston (MA)    21      25       25        0
# 1   Portland (OR)    14      15       15        0

# %%
all_data['Order Date'] = pd.to_numeric(all_data['Order Date'])
product_group = all_data.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']

products = [product for product, df in product_group]

plt.bar(products, quantity_ordered)
plt.ylabel('Quantity Ordered')
plt.xlabel('Product')

plt.xticks(products, rotation='vertical', size=8)

plt.show()
# Out:
# /tmp/ipykernel_159023/2429912528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Order Date'] = pd.to_numeric(all_data['Order Date'])

# %%
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])
prices =all_data.groupby('Product')['Price Each'].mean()

fiq, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(products, quantity_ordered, color='g')
ax2.plot(products, prices, 'b-')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(products, rotation='vertical', size=8)

plt.show()
# Out:
# /tmp/ipykernel_159023/57016760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])
# /tmp/ipykernel_159023/57016760.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(products, rotation='vertical', size=8)

# %% [markdown]
# **Answer: AAA Batteries(4-pack), because it price is low, hence more demand**
